# %% [markdown]
# ### Instances
# ```
# machines =              [ 5, 10, 25,  50,  75, 100]
# jobs     = 2*machines = [10, 20, 50, 100, 150, 200]
#
# instances = [
#   ( 10,  5),
#   ( 20, 10),
#   ( 50, 25),
#   (100, 50),
#   (150, 75),
#   (200, 100)
# ]
# ```
# ### Epsilons
# ```
# eps = [
#   0.1,
#   0.05,
#   0.01
# ]
# ```
# ### Seeds
# ```
# seeds = [1, ..., 200]
# ```
